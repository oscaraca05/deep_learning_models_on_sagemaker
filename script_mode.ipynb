# %%
from sagemaker.pytorch import PyTorch
from sagemaker import get_execution_role

hyperparameters = {"epochs": "2", 
                  "batch-size":"32", 
                  "test-batch-size":"100", 
                  "lr":"0.001"}# TODO: Include the hyperparameters your script will need over here.

estimator = PyTorch(
    entry_point="scripts/pytorch_cifar.py", 
    base_job_name="sagemaker-script-mode", 
    role=get_execution_role(), 
    instance_count=1, 
    instance_type="ml.m5.large", 
    hyperparameters=hyperparameters, 
    framework_version="1.8", 
    py_version="py36") 
# TODO: Create your estimator here. You can use Pytorch or any other framework.

#TODO: Start Training
estimator.fit(wait=True)
# Out:
# 2022-11-07 23:32:07 Starting - Starting the training job...
# 2022-11-07 23:32:30 Starting - Preparing the instances for trainingProfilerReport-1667863927: InProgress
# ......
# 2022-11-07 23:33:30 Downloading - Downloading input data......
# 2022-11-07 23:34:31 Training - Downloading the training image.....bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-11-07 23:35:11,976 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-11-07 23:35:11,979 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-07 23:35:11,988 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-11-07 23:35:11,995 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-11-07 23:35:12,457 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-07 23:35:12,470 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-07 23:35:12,481 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-07 23:35:12,490 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": "32",
#         "epochs": "2",
#         "lr": "0.001",
#         "test-batch-size": "100"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-script-mode-2022-11-07-23-32-06-975",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-155431344840/sagemaker-script-mode-2022-11-07-23-32-06-975/source/sourcedir.tar.gz",
#     "module_name": "pytorch_cifar",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.large",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.large",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "pytorch_cifar.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":"32","epochs":"2","lr":"0.001","test-batch-size":"100"}
# SM_USER_ENTRY_POINT=pytorch_cifar.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=pytorch_cifar
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-155431344840/sagemaker-script-mode-2022-11-07-23-32-06-975/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":"32","epochs":"2","lr":"0.001","test-batch-size":"100"},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-script-mode-2022-11-07-23-32-06-975","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-155431344840/sagemaker-script-mode-2022-11-07-23-32-06-975/source/sourcedir.tar.gz","module_name":"pytorch_cifar","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.large","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.large"}],"network_interface_name":"eth0"},"user_entry_point":"pytorch_cifar.py"}
# SM_USER_ARGS=["--batch-size","32","--epochs","2","--lr","0.001","--test-batch-size","100"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH-SIZE=32
# SM_HP_EPOCHS=2
# SM_HP_LR=0.001
# SM_HP_TEST-BATCH-SIZE=100
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.6 pytorch_cifar.py --batch-size 32 --epochs 2 --lr 0.001 --test-batch-size 100
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
# Extracting ../data/cifar-10-python.tar.gz to ../data
# [2022-11-07 23:35:19.028 algo-1:28 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-11-07 23:35:19.406 algo-1:28 INFO profiler_config_parser.py:102] User has disabled profiler.
# [2022-11-07 23:35:19.407 algo-1:28 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-11-07 23:35:19.408 algo-1:28 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-11-07 23:35:19.408 algo-1:28 INFO hook.py:255] Saving to /opt/ml/output/tensors
# [2022-11-07 23:35:19.408 algo-1:28 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:591] name:conv1.weight count_params:864
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:591] name:conv1.bias count_params:32
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:591] name:conv2.weight count_params:18432
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:591] name:conv2.bias count_params:64
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:591] name:fc1.weight count_params:1605632
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:591] name:fc1.bias count_params:128
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:591] name:fc2.weight count_params:1280
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:591] name:fc2.bias count_params:10
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:593] Total Trainable Params: 1626442
# [2022-11-07 23:35:19.434 algo-1:28 INFO hook.py:425] Monitoring the collections: losses
# [2022-11-07 23:35:19.436 algo-1:28 INFO hook.py:488] Hook is writing from the hook with pid: 28
# Train Epoch: 1 [0/50000 (0%)]#011Loss: 2.297040
#
# 2022-11-07 23:35:31 Training - Training image download completed. Training in progress.Train Epoch: 1 [3200/50000 (6%)]#011Loss: 2.296530
# Train Epoch: 1 [6400/50000 (13%)]#011Loss: 2.298767
# Train Epoch: 1 [9600/50000 (19%)]#011Loss: 2.292142
# Train Epoch: 1 [12800/50000 (26%)]#011Loss: 2.296607
# Train Epoch: 1 [16000/50000 (32%)]#011Loss: 2.305184
# Train Epoch: 1 [19200/50000 (38%)]#011Loss: 2.297146
# Train Epoch: 1 [22400/50000 (45%)]#011Loss: 2.302717
# Train Epoch: 1 [25600/50000 (51%)]#011Loss: 2.320170
# Train Epoch: 1 [28800/50000 (58%)]#011Loss: 2.293298
# Train Epoch: 1 [32000/50000 (64%)]#011Loss: 2.276731
# Train Epoch: 1 [35200/50000 (70%)]#011Loss: 2.283455
# Train Epoch: 1 [38400/50000 (77%)]#011Loss: 2.292729
# Train Epoch: 1 [41600/50000 (83%)]#011Loss: 2.287843
# Train Epoch: 1 [44800/50000 (90%)]#011Loss: 2.282313
# Train Epoch: 1 [48000/50000 (96%)]#011Loss: 2.272902
# Test set: Average loss: 2.2802, Accuracy: 1451/10000 (15%)
# Train Epoch: 2 [0/50000 (0%)]#011Loss: 2.294359
# Train Epoch: 2 [3200/50000 (6%)]#011Loss: 2.288670
# Train Epoch: 2 [6400/50000 (13%)]#011Loss: 2.266510
# Train Epoch: 2 [9600/50000 (19%)]#011Loss: 2.278417
# Train Epoch: 2 [12800/50000 (26%)]#011Loss: 2.252569
# Train Epoch: 2 [16000/50000 (32%)]#011Loss: 2.276964
# Train Epoch: 2 [19200/50000 (38%)]#011Loss: 2.276540
# Train Epoch: 2 [22400/50000 (45%)]#011Loss: 2.258534
# Train Epoch: 2 [25600/50000 (51%)]#011Loss: 2.239434
# Train Epoch: 2 [28800/50000 (58%)]#011Loss: 2.293373
# Train Epoch: 2 [32000/50000 (64%)]#011Loss: 2.238625
# Train Epoch: 2 [35200/50000 (70%)]#011Loss: 2.260420
# Train Epoch: 2 [38400/50000 (77%)]#011Loss: 2.274843
# Train Epoch: 2 [41600/50000 (83%)]#011Loss: 2.230066
# Train Epoch: 2 [44800/50000 (90%)]#011Loss: 2.241250
# Train Epoch: 2 [48000/50000 (96%)]#011Loss: 2.203987
# Test set: Average loss: 2.2332, Accuracy: 1918/10000 (19%)
# #015  0%|          | 0/170498071 [00:00<?, ?it/s]#015  0%|          | 820224/170498071 [00:00<00:23, 7215359.13it/s]#015  6%|▌         | 10372096/170498071 [00:00<00:02, 56364724.85it/s]#015 13%|█▎        | 22120448/170498071 [00:00<00:01, 83436961.11it/s]#015 20%|█▉        | 33883136/170498071 [00:00<00:01, 96656783.13it/s]#015 27%|██▋       | 45645824/170498071 [00:00<00:01, 104127061.70it/s]#015 34%|███▎      | 57395200/170498071 [00:00<00:01, 108635437.31it/s]#015 41%|████      | 69141504/170498071 [00:00<00:00, 111505833.47it/s]#015 47%|████▋     | 80902144/170498071 [00:00<00:00, 113439243.25it/s]#015 54%|█████▍    | 92587008/170498071 [00:00<00:00, 114497893.90it/s]#015 61%|██████    | 104335360/170498071 [00:01<00:00, 115417841.64it/s]#015 68%|██████▊   | 116098048/170498071 [00:01<00:00, 116057426.11it/s]#015 75%|███████▍  | 127717376/170498071 [00:01<00:00, 110594928.57it/s]#015 82%|████████▏ | 139655168/170498071 [00:01<00:00, 113163531.29it/s]#015 89%|████████▊ | 151226368/170498071 [00:01<00:00, 113914000.33it/s]#015 96%|█████████▌| 163070976/170498071 [00:01<00:00, 115238911.64it/s]#015170499072it [00:01, 106917431.66it/s]
# 2022-11-07 23:39:26,262 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2022-11-07 23:39:52 Uploading - Uploading generated training model
# 2022-11-07 23:39:52 Completed - Training job completed
# Training seconds: 378
# Billable seconds: 378
